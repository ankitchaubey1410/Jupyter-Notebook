# %% [markdown]
# ## EXECEPTION HANDLING

# %% [markdown]
# ###### There are two stages where error may appear in a program
# ###### 1.During compilation - Syntax error
# ###### 2.During execution - Exceptions

# %% [markdown]
# #### Syntax Error
# ###### 1.Something is not written according to the program grammer.
# ###### 2.This error is detected by the compiler / interpreter.
# ###### 3.You can solve it by correcting the program.

# %%
# Example of syntax error
print 'ichigo'
# Out:
#   Cell In[1], line 2
#     print 'ichigo'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Corrected code
print('ichigo')
# Out:
# ichigo

# %% [markdown]
# #### Other examples of syntax error
# ###### 1.misspelling a keyword
# ###### 2.not using indentation
# ###### 3.empty for, loop, funtion, if else
# ###### 4.leaving symbols like colon, comma or brackets

# %%
a = 4
for i in range(a)
    print(i)
# Out:
#   Cell In[3], line 2
#     for i in range(a)
#                      ^
# SyntaxError: expected ':'

# %%
a = 6
iff a == 4:
    print(a)
# Out:
#   Cell In[4], line 2
#     iff a == 4:
#         ^
# SyntaxError: invalid syntax

# %%
# This is a syntax error but python identify it as indentation error
a = 5
for i in range(a):
print(a)
# Out:
#   Cell In[5], line 4
#     print(a)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
# IndexError
# This error is thrown when trying to access an item at invalid index
L = [1,2,3,4,5,6]
L[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 # IndexError
#       2 # This error is thrown when trying to access an item at invalid index
#       3 L = [1,2,3,4,5,6]
# ----> 4 L[7]
#
# IndexError: list index out of range

# %%
# ModuleNotFoundError
# This error is thrown when a module is couldn't be found
import maths
math.sqrt(4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 # ModuleNotFoundError
#       2 # This error is thrown when a module is couldn't be found
# ----> 3 import maths
#       4 math.sqrt(4)
#
# ModuleNotFoundError: No module named 'maths'

# %%
# KeyError
# This error is thrown when a key is not found
d = {'name':'Ankit','age':19}
d['rollno']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       1 # KeyError
#       2 # This error is thrown when a key is not found
#       3 d = {'name':'Ankit','age':19}
# ----> 4 d['rollno']
#
# KeyError: 'rollno'

# %%
# TypeError
# This error is thrown when an operation or function is appilied to an inappropriate type
a = 999
a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 # TypeError
#       2 # This error is thrown when an operation or function is appilied to an inappropriate type
#       3 a = 999
# ----> 4 a[1]
#
# TypeError: 'int' object is not subscriptable

# %%
# ValueError
# This error is thrown when a function's argument is of inappropriate type
float('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 # ValueError
#       2 # This error is thrown when a function's argument is of inappropriate type
# ----> 3 float('a')
#
# ValueError: could not convert string to float: 'a'

# %%
# NameError
# This error is thrown when an object is not found
name = 'Shreya'
print(names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 # NameError
#       2 # This error is thrown when an object is not found
#       3 name = 'Shreya'
# ----> 4 print(names)
#
# NameError: name 'names' is not defined

# %%
# AttributeError
# This error occurs when you try to access an attribute that an object does not have.
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 # AttributeError
#       2 # This error occurs when you try to access an attribute that an object does not have.
#       3 L = [1,2,3]
# ----> 4 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# #### Exceptions
# ###### If things go wrong during the execution of the program(runtime). It generally happens when something unforeseen had happened.
# ###### 1.Exceptions are raised by python runtime.
# ###### 2.You have to takle is on the fly.

# %% [markdown]
# #### Examples
# ###### 1.Memory overflow
# ###### 2.Divide by 0 -> Logical error
# ###### 3.Database error

# %%
L = [1,2,3]
L.upper()
# Below this box is Stacktrace which tells about error appeared in which line and what is that error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 L = [1,2,3]
# ----> 2 L.upper()
#       3 # Below this box is Stacktrace which tells about error appeared in which line and what is that error
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# ###### How to handle exceptions?
# ###### -> Try except block

# %%
# Lets create a file
with open('sample.txt','w') as fin:
    fin.write('Hello world')

# %%
with open('sample1.txt','r') as fin:
    print(fin.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 with open('sample1.txt','r') as fin:
#       2     print(fin.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample1.txt'

# %%
# try catch demo
try:
    with open('sample1.txt','r') as fin:
        print(fin.read())
except:
    print('sorry file not found')

# In C++ it is called catch
# Out:
# sorry file not found

# %%
# catching specific exception
try:
    with open('sample1.txt','r') as fin:
        print(fin.read())
        print(m)
        print(4/0)
        L = [1,2,3,4,5,6]
        L[100]
except FileNotFoundError:
    print('sorry file not found')
except NameError:
    print('sorry variable not defined')
except Exception as e:
    print(e)
except Exception as e:
    print(e.with_traceback)

# e.with_traceback(tb) is a method on exception objects that returns the same exception instance with a specific traceback attached.
# Out:
# sorry file not found

# %%
# else
# The else block executes only if the try block completes successfully without raising an exception.
try:
    fin = open('sample1.txt','r')
except FileNotFoundError:
    print('file nahi mili')
except Exception:
    print('kuch toh dikkat hai bhaiya')
else:
    print(fin.read())
# Out:
# file nahi mili

# %%
# finally
# The finally block is used to execute important cleanup code that must run regardless of whether an exception occurs or not, such as closing files, database connections, or releasing resources.
try:
    fin = open('sample1.txt','r')
except FileNotFoundError:
    print('file nahi mili')
except Exception:
    print('kuch toh dikkat hai bhaiya')
else:
    print(fin.read())
finally:
    print('yeh toh print hoga hi hoga')
    fin.close()
# Out:
# file nahi mili
# yeh toh print hoga hi hoga

# %%
# raise Exception
# In Python, exceptions are raised when an errors occur at runtime.
# We can also manually raise exceptions using the raise keyword.
# We can optionally pass values to the exception to clarify why that exception was raised
# In C++ it is called throw

# %%
raise FileNotFoundError('just trying')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 raise FileNotFoundError('just trying')
#
# FileNotFoundError: just trying

# %%
# Example 1

class Bank:
    def __init__(self, balance):
        self.balance = balance
    def withdraw(self, amount):
        if amount < 0:
            raise Exception("amount cannot be -ve")
        if self.balance < amount:
            raise Exception("paise nahi hai apke paas")
        self.balance = self.balance - amount
        print(f"Withdrawal successful. Remaining balance = {self.balance}")
obj = Bank(10000)
try:
    obj.withdraw(-5000)
except Exception as e:
    print(e)
else:
    print(obj.balance)
finally:
    print("Thankyou for visiting our Bank")
# Out:
# amount cannot be -ve
# Thankyou for visiting our Bank

# %%
# Example 2

age = -25
if age < 0:
    raise ValueError("Age kabhi bhi -ve nhi ho sakhti")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 5
#       1 # Example 2
#       2
#       3 age = -25
#       4 if age < 0:
# ----> 5     raise ValueError("Age kabhi bhi -ve nhi ho sakhti")
#
# ValueError: Age kabhi bhi -ve nhi ho sakhti

# %% [markdown]
# ![image.png](attachment:c4c28387-19dc-4940-a002-8c3c2f2e4ce8.png)![image.png](attachment:214f971b-4c17-4456-9e93-e57669fc8d04.png)

# %%
# creating custom exceptions
# Custom exceptions let you create your own meaningful error types for problems that are specific to your program.

class MyException(Exception):
    def __init__(self,message):
        print(message)
class Bank:
    def __init__(self, balance):
        self.balance = balance
    def withdraw(self, amount):
        if amount < 0:
            raise MyException("amount cannot be -ve")
        if self.balance < amount:
            raise MyException("paise nahi hai apke paas")
        self.balance = self.balance - amount
        print(f"Withdrawal successful. Remaining balance = {self.balance}")
obj = Bank(10000)
try:
    obj.withdraw(-5000)
except MyException as e:
    pass
else:
    print(obj.balance)
finally:
    print("Thankyou for visiting our Bank")
# Out:
# amount cannot be -ve
# Thankyou for visiting our Bank

# %%
# Google wala example
class SecurityError(Exception):
    def __init__(self,message):
        print(message)
    def logout(self):
        print('logout from all devices')

class Google:

    def __init__(self,name,email,password,device):
        self.name = name
        self.email = email
        self.password = password
        self.device = device

    def login(self,email,password,device):
        if device != self.device:
            raise SecurityError('bhai teri device multiple device mein login hai')
        if email == self.email and password == self.password:
            print('welcome')
        else:
            print('login error')
obj = Google('nitish','nitish@gmail.com','1234','android')

try:
    obj.login('nitish@gmail.com','1234','ios')
except SecurityError as e:
    e.logout()
else :
    print(obj.name)
finally :
    print('database connection closed')
# Out:
# bhai teri device multiple device mein login hai
# logout from all devices
# database connection closed

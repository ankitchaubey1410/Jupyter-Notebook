# %% [markdown]
# ## Range Example

# %%
for i in range (1,43,4):
    print(i)
# Out:
# 1
# 5
# 9
# 13
# 17
# 21
# 25
# 29
# 33
# 37
# 41

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# for line numbers show press SHIFT + L

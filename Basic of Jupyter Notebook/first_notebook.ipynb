# %% [markdown]
# # Printing Text

# %%
print("my first girlfriend is koffee saha")
# Out:
# my first girlfriend is koffee saha

# %% [markdown]
# ## Printing List

# %%
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Printing Calculations

# %%
print(2*2*9)
# Out:
# 36

# %% [markdown]
# ##### FIRST NOTEBOOK PRINTED

# %%
print("This is my first jupyter notebook")
# Out:
# This is my first jupyter notebook

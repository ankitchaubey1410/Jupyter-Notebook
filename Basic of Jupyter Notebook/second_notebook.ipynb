# %% [markdown]
# # Python Program

# %% [markdown]
# ## Displaying Calculations

# %%
print(3+3+4+1)
# Out:
# 11

# %% [markdown]
# ## Displaying Text

# %%
print("koffee here...")
# Out:
# koffee here...

# %% [markdown]
# ## Displaying Numbers

# %%
print(65)
# Out:
# 65

# %% [markdown]
# ## What are raw cells?

# %% [raw]
# # raw cells are the entire notebook cell which is not excueted and render by jupyter

# %% [markdown]
# ## What are markdown cells?

# %% [raw]
# # markdown cells are used as formatted texts , notes , and explanation along side code

# %% [markdown]
# ## What are code cells?

# %% [raw]
# # code cells are for executing for a code by jupyter to reach its final output

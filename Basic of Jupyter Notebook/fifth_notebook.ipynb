# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
# dataset
data = {
    'student' : ["koffee" , "coke" , "beer" , "milkshake" , "lassi"],
    'rank' : [1 , 4 , 3 , 2 , 5],
    'marks' : [90 , 70 , 80 , 65 , 90]
}
res = pd.DataFrame(data)

print("Student Records\n\n",res)
# Out:
# Student Records
#
#       student  rank  marks
# 0     koffee     1     90
# 1       coke     4     70
# 2       beer     3     80
# 3  milkshake     2     65
# 4      lassi     5     90
